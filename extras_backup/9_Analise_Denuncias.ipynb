# %% [markdown]
# # Análise das denúncias de poluição sonora
# Exploração tabular do arquivo `mga_denuncias_20-23.geojson`, com foco nos campos gerados pelo pipeline de NLP (tokens, contexto, modalidade e horários).

# %%
import json
from pathlib import Path

import pandas as pd

GEOJSON_PATH = Path("mga_denuncias_20-23.geojson")

with GEOJSON_PATH.open() as fh:
    geojson = json.load(fh)

df = pd.json_normalize(
    geojson["features"],
    record_path=None,
    meta=["type"],
)
properties_cols = [col for col in df.columns if col.startswith("properties.")]
df_properties = df[properties_cols].rename(columns=lambda c: c.removeprefix("properties."))
df_properties.head()
# Out:
#   Protocolo                                   Endereço Número  \
# 0    649554                      Alameda Amor Perfeito     36
# 1    601042                      Alameda Das Alfazemas   1968
# 2    660699                Alameda Doutor João Paulino    673
# 3    784845  Avenida Advogado Horácio Raccanello Filho    183
# 4    648166  Avenida Advogado Horácio Raccanello Filho   3605
#
#                     Bairro Zona               Setor         DataInclusao  \
# 0         Zona 04 - centro   60  IAM - Fiscalização  2022-11-14 22:20:00
# 1                   Zona 3   60  IAM - Fiscalização  2022-05-21 23:54:00
# 2  JARDIM ALVORADA I PARTE   24  IAM - Fiscalização  2022-12-23 23:49:00
# 3                Vila nova   18  IAM - Fiscalização  2023-12-23 08:56:00
# 4             ZONA ARMAZÉM    9  IAM - Fiscalização  2022-11-09 08:45:00
#
#      Cadastro                                        Assunto  \
# 0    60130700  Poluição sonora por estabelecimento comercial
# 1    60067500  Poluição sonora por estabelecimento comercial
# 2  24130900.0  Poluição sonora por estabelecimento comercial
# 3  18039700.0  Poluição sonora por estabelecimento comercial
# 4   9014300.0  Poluição sonora por estabelecimento comercial
#
#                                            Descrição  ... tipo_fonte_score  \
# 0  Som ao vivo fora do estabelecimento provocando...  ...                2
# 1  Muito barulho som alto de dois bares thel bar ...  ...                1
# 2  Vizinho vários dias com som alto além da hora....  ...                1
# 3  Esse estabelecimento permanece com o som alto ...  ...                2
# 4  na madrugada de terça para quarta (dia 08 para...  ...                1
#
#   tipo_fonte_termos fonte_cluster fonte_contexto fonte_contexto_score  \
# 0       [som, vivo]     cluster_2     bar_evento                    1
# 1             [som]     cluster_0     bar_evento                    1
# 2             [som]     cluster_0    residencial                    2
# 3     [música, som]     cluster_2     bar_evento                    2
# 4             [som]     cluster_2                                   0
#
#             fonte_contexto_termos fonte_audio fonte_audio_score  \
# 0               [estabelecimento]      musica                 2
# 1                           [bar]      musica                 1
# 2                 [casa, vizinho]      musica                 1
# 3  [estabelecimento, residencial]      musica                 2
# 4                              []      musica                 1
#
#   fonte_audio_termos               fonte_horario
# 0        [som, vivo]                     [manha]
# 1              [som]                          []
# 2              [som]                     [noite]
# 3      [música, som]                          []
# 4              [som]  [madrugada, fim_de_semana]
#
# [5 rows x 29 columns]

# %%
df_properties[[
    "Protocolo",
    "Bairro",
    "Descrição",
    "descricao_tokens",
    "fonte_contexto",
    "fonte_audio",
    "Tipo de Fonte",
    "fonte_horario",
]].head(10)
# Out:
#   Protocolo                   Bairro  \
# 0    649554         Zona 04 - centro
# 1    601042                   Zona 3
# 2    660699  JARDIM ALVORADA I PARTE
# 3    784845                Vila nova
# 4    648166             ZONA ARMAZÉM
# 5    649328             ZONA ARMAZÉM
# 6    656895             ZONA ARMAZÉM
# 7    674293             ZONA ARMAZÉM
# 8    704468             ZONA ARMAZÉM
# 9    648219                   ZONA 3
#
#                                            Descrição  \
# 0  Som ao vivo fora do estabelecimento provocando...
# 1  Muito barulho som alto de dois bares thel bar ...
# 2  Vizinho vários dias com som alto além da hora....
# 3  Esse estabelecimento permanece com o som alto ...
# 4  na madrugada de terça para quarta (dia 08 para...
# 5               batucada religiosa fora de contesto.
# 6  Agora sao 23:20h do dia 10/12 e a tenda de umb...
# 7  agora são 22;48 do dia 06/02/2023 (segunda fei...
# 8  a tenda de umbanda novamente esta desrepeitand...
# 9  Por gentileza notificar essa Tenda de Umbanda ...
#
#                                     descricao_tokens fonte_contexto  \
# 0  [som, vivo, estabelecimento, provocar, incômod...     bar_evento
# 1  [som, alto, bar, thel, bar, espetinho, insupor...     bar_evento
# 2  [vizinho, vários, dia, som, alto, além, hora, ...    residencial
# 3  [estabelecimento, permanecer, som, alto, após,...     bar_evento
# 4  [madrugada, terça, quarta, dia, novembro, tend...
# 5                    [batucada, religioso, contesto]
# 6  [agora, sao, dia, tenda, umbanda, amigo, axé, ...
# 7  [agora, dia, segundo, feira, tenda, umbanda, c...
# 8  [tenda, umbanda, novamente, desrepeitar, lei, ...
# 9  [gentileza, notificar, tenda, umbanda, amigo, ...     bar_evento
#
#   fonte_audio       Tipo de Fonte               fonte_horario
# 0      musica   bar_evento_musica                     [manha]
# 1      musica   bar_evento_musica                          []
# 2      musica  residencial_musica                     [noite]
# 3      musica   bar_evento_musica                          []
# 4      musica              musica  [madrugada, fim_de_semana]
# 5                      indefinido                          []
# 6      musica              musica             [fim_de_semana]
# 7      musica              musica             [fim_de_semana]
# 8      musica              musica             [fim_de_semana]
# 9      musica   bar_evento_musica                 [madrugada]

# %%
summary = (
    df_properties["Tipo de Fonte"]
    .value_counts()
    .rename_axis("Tipo de Fonte")
    .reset_index(name="Denúncias")
)
summary
# Out:
#                           Tipo de Fonte  Denúncias
# 0                     bar_evento_musica       1245
# 1                                musica        344
# 2                            bar_evento        155
# 3                    residencial_musica        148
# 4                            indefinido         90
# 5                    via_publica_musica         80
# 6                       obra_construcao         55
# 7          bar_evento_vozes_aglomeracao         32
# 8                  igreja_templo_musica         30
# 9                     area_lazer_musica         25
# 10           obra_construcao_maquinario         24
# 11               obra_construcao_musica         24
# 12                          residencial         23
# 13                   bar_evento_veiculo         21
# 14                    industria_servico         20
# 15                bar_evento_maquinario         19
# 16                          via_publica         18
# 17             industria_servico_musica         15
# 18                        igreja_templo         14
# 19         industria_servico_maquinario         14
# 20            industria_servico_veiculo         14
# 21                    bar_evento_alarme         13
# 22               residencial_maquinario         13
# 23                           maquinario         12
# 24                  residencial_veiculo         12
# 25            veiculos_transito_veiculo         11
# 26             veiculos_transito_musica         11
# 27                               alarme          9
# 28               obra_construcao_alarme          8
# 29                  via_publica_veiculo          8
# 30                               animal          5
# 31        residencial_vozes_aglomeracao          5
# 32                    vozes_aglomeracao          5
# 33                     bar_evento_fogos          5
# 34               via_publica_maquinario          4
# 35                              veiculo          4
# 36                   residencial_animal          4
# 37              obra_construcao_veiculo          4
# 38                           area_lazer          3
# 39  industria_servico_vozes_aglomeracao          3
# 40                   via_publica_alarme          3
# 41                   residencial_alarme          3
# 42             industria_servico_animal          3
# 43      igreja_templo_vozes_aglomeracao          2
# 44             industria_servico_alarme          2
# 45                                fogos          2
# 46                    bar_evento_animal          1
# 47                    via_publica_fogos          1
# 48                   via_publica_animal          1
# 49              industria_servico_fogos          1
# 50    obra_construcao_vozes_aglomeracao          1
# 51             veiculos_transito_alarme          1
# 52        via_publica_vozes_aglomeracao          1
# 53         veiculos_transito_maquinario          1

# %%
cross_context_audio = (
    df_properties.groupby(["fonte_contexto", "fonte_audio"]).size().reset_index(name="Denúncias")
)
cross_context_audio.sort_values("Denúncias", ascending=False).head(20)
# Out:
#        fonte_contexto        fonte_audio  Denúncias
# 15         bar_evento             musica       1245
# 5                                 musica        344
# 10         bar_evento                           155
# 39        residencial             musica        148
# 0                                                90
# 51        via_publica             musica         80
# 29    obra_construcao                            55
# 17         bar_evento  vozes_aglomeracao         32
# 19      igreja_templo             musica         30
# 9          area_lazer             musica         25
# 31    obra_construcao         maquinario         24
# 32    obra_construcao             musica         24
# 35        residencial                            23
# 16         bar_evento            veiculo         21
# 21  industria_servico                            20
# 14         bar_evento         maquinario         19
# 46        via_publica                            18
# 26  industria_servico             musica         15
# 25  industria_servico         maquinario         14
# 27  industria_servico            veiculo         14

# %%
horario_explode = df_properties.explode("fonte_horario")
horario_summary = (
    horario_explode["fonte_horario"].dropna().value_counts().rename_axis("Horário").reset_index(name="Denúncias")
)
horario_summary
# Out:
#          Horário  Denúncias
# 0          noite        559
# 1  fim_de_semana        549
# 2          manha        465
# 3      madrugada        425
# 4          tarde        170
