# %% [markdown]
# ![k-mean clustering](./img/clustering.png)

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"

# %%
import pandas as pd

from sklearn.cluster import KMeans
import folium

import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
# %matplotlib inline
# %matplotlib inline

# %%
df = pd.read_csv(r"geocod_parcial_corrigido.csv")
df.head()
# Out:
#    Protocolo                                   Endereço  Número  \
# 0     649554                      Alameda Amor Perfeito      36
# 1     601042                      Alameda Das Alfazemas    1968
# 2     660699                Alameda Doutor João Paulino     673
# 3     784845  Avenida Advogado Horácio Raccanello Filho     183
# 4     648166  Avenida Advogado Horácio Raccanello Filho    3605
#
#                     Bairro Zona               Setor         DataInclusao  \
# 0         Zona 04 - centro   60  IAM - Fiscalização  2022-11-14 22:20:00
# 1                   Zona 3   60  IAM - Fiscalização  2022-05-21 23:54:00
# 2  JARDIM ALVORADA I PARTE   24  IAM - Fiscalização  2022-12-23 23:49:00
# 3                Vila nova   18  IAM - Fiscalização  2023-12-23 08:56:00
# 4             ZONA ARMAZÉM    9  IAM - Fiscalização  2022-11-09 08:45:00
#
#      Cadastro                                        Assunto  \
# 0    60130700  Poluição sonora por estabelecimento comercial
# 1    60067500  Poluição sonora por estabelecimento comercial
# 2  24130900.0  Poluição sonora por estabelecimento comercial
# 3  18039700.0  Poluição sonora por estabelecimento comercial
# 4   9014300.0  Poluição sonora por estabelecimento comercial
#
#                                            Descrição         Origem   Cidade  \
# 0  Som ao vivo fora do estabelecimento provocando...  Identificados  Maringá
# 1  Muito barulho som alto de dois bares thel bar ...  Identificados  Maringá
# 2  Vizinho vários dias com som alto além da hora....      Sigilosos  Maringá
# 3  Esse estabelecimento permanece com o som alto ...      Sigilosos  Maringá
# 4  na madrugada de terça para quarta (dia 08 para...      Sigilosos  Maringá
#
#    Estado    Pais      DataInclusao_BR  \
# 0  Paraná  Brasil  22:20:00 14-11-2022
# 1  Paraná  Brasil  23:54:00 21-05-2022
# 2  Paraná  Brasil  23:49:00 23-12-2022
# 3  Paraná  Brasil  08:56:00 23-12-2023
# 4  Paraná  Brasil  08:45:00 09-11-2022
#
#                                    endereco_completo   latitude  longitude  \
# 0    Alameda Amor Perfeito, 36, Maringá - PR, Brasil -23.360488 -52.014885
# 1  Alameda Das Alfazemas, 1968, Maringá - PR, Brasil -23.357035 -52.009594
# 2  Alameda Doutor João Paulino, 673, Maringá - PR... -23.400397 -51.921264
# 3  Avenida Advogado Horácio Raccanello Filho, 183... -23.420447 -51.924922
# 4  Avenida Advogado Horácio Raccanello Filho, 360... -23.423895 -51.914974
#
#                                   endereco_formatado
# 0  Alameda Amor Perfeito - Conj. Hab. Joao de Bar...
# 1  Alameda das Alfazemas - Conj. Hab. Joao de Bar...
# 2  Alameda Dr. João Paulino, 673 - Jardim Alvorad...
# 3  Av. Advogado Horácio Raccanello Filho, 183 - Z...
# 4  Av. Advogado Horácio Raccanello Filho, 3605 - ...

# %%
x = df[["latitude", "longitude"]]
x.head()
# Out:
#     latitude  longitude
# 0 -23.360488 -52.014885
# 1 -23.357035 -52.009594
# 2 -23.400397 -51.921264
# 3 -23.420447 -51.924922
# 4 -23.423895 -51.914974

# %%
import numpy as np
from sklearn.cluster import OPTICS

# Seleciona latitude e longitude
x = df[["latitude", "longitude"]]

# Converte para radianos
x_rad = np.radians(x)

# Cria o modelo OPTICS (sem max_eps definido)
clustering = OPTICS(metric='haversine')

# Ajusta e gera os rótulos
df['cluster'] = clustering.fit_predict(x_rad)

# Vê a distribuição de clusters
print(df['cluster'].value_counts())
# Out:
# cluster
# -1      459
#  107    140
#  123    102
#  80      86
#  64      74
#        ...
#  62       5
#  160      5
#  159      5
#  144      5
#  98       5
# Name: count, Length: 167, dtype: int64
# /opt/anaconda3/envs/machine_learning/lib/python3.12/site-packages/sklearn/cluster/_optics.py:1084: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
# ===================== CODE BLOCK 12-9 =====================
# Remove os outliers (cluster = -1)
from shapely import Point


df_clean = df[df['cluster'] != -1].copy()

# ===================== CODE BLOCK 12-10 =====================
# Calcula medianas por cluster
medians_of_POI = (
    df_clean.groupby('cluster')[['latitude', 'longitude']]
    .median()
    .reset_index(drop=False)
)

print(medians_of_POI)

# ===================== CODE BLOCK 12-11 =====================
# Cria GeoDataFrame com os centróides
medians_of_POI_gdf = gpd.GeoDataFrame(
    medians_of_POI,
    geometry=[Point(xy) for xy in zip(medians_of_POI['longitude'], medians_of_POI['latitude'])],
    crs="EPSG:4326"
)

# Plota: centróides em vermelho
ax = medians_of_POI_gdf.plot(color='red', figsize=(6,6))
plt.show()
# Out:
#      cluster   latitude  longitude
# 0          0 -23.380143 -51.967073
# 1          1 -23.383806 -51.952089
# 2          2 -23.383755 -51.951999
# 3          3 -23.384104 -51.952154
# 4          4 -23.376677 -51.958253
# ..       ...        ...        ...
# 161      161 -23.432336 -51.977404
# 162      162 -23.445222 -51.973393
# 163      163 -23.451671 -51.982688
# 164      164 -23.441071 -51.895595
# 165      165 -23.368862 -52.066304
#
# [166 rows x 3 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# cria geometria dos pontos centrais
medians_of_POI_gdf = gpd.GeoDataFrame(
    medians_of_POI,
    geometry=[Point(xy) for xy in zip(medians_of_POI['longitude'], medians_of_POI['latitude'])],
    crs="EPSG:4326"   # CRS original: graus decimais WGS84
)

# opção 1: plot direto com geopandas (sem marker/color customizados)
ax = medians_of_POI_gdf.plot(color='red', figsize=(6,6))

# opção 2: plot manual com matplotlib (mais flexível)
fig, ax = plt.subplots(figsize=(6,6))
plt.scatter(medians_of_POI['longitude'], medians_of_POI['latitude'], 
            c='red', s=50, marker='o')
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Centros (medianas) dos clusters")
plt.show()

# %%
model = KMeans(n_clusters=4)
y_kmeans = model.fit_predict(x)

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"
import pandas as pd

from sklearn.cluster import KMeans
import folium

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %matplotlib inline

# %%
model = KMeans(n_clusters=4)
y_kmeans = model.fit_predict(x)

# %%
df['y'] = y_kmeans

# %%
df.head()
# Out:
#    Protocolo                                   Endereço  Número  \
# 0     649554                      Alameda Amor Perfeito      36
# 1     601042                      Alameda Das Alfazemas    1968
# 2     660699                Alameda Doutor João Paulino     673
# 3     784845  Avenida Advogado Horácio Raccanello Filho     183
# 4     648166  Avenida Advogado Horácio Raccanello Filho    3605
#
#                     Bairro Zona               Setor         DataInclusao  \
# 0         Zona 04 - centro   60  IAM - Fiscalização  2022-11-14 22:20:00
# 1                   Zona 3   60  IAM - Fiscalização  2022-05-21 23:54:00
# 2  JARDIM ALVORADA I PARTE   24  IAM - Fiscalização  2022-12-23 23:49:00
# 3                Vila nova   18  IAM - Fiscalização  2023-12-23 08:56:00
# 4             ZONA ARMAZÉM    9  IAM - Fiscalização  2022-11-09 08:45:00
#
#      Cadastro                                        Assunto  \
# 0    60130700  Poluição sonora por estabelecimento comercial
# 1    60067500  Poluição sonora por estabelecimento comercial
# 2  24130900.0  Poluição sonora por estabelecimento comercial
# 3  18039700.0  Poluição sonora por estabelecimento comercial
# 4   9014300.0  Poluição sonora por estabelecimento comercial
#
#                                            Descrição  ...   Cidade  Estado  \
# 0  Som ao vivo fora do estabelecimento provocando...  ...  Maringá  Paraná
# 1  Muito barulho som alto de dois bares thel bar ...  ...  Maringá  Paraná
# 2  Vizinho vários dias com som alto além da hora....  ...  Maringá  Paraná
# 3  Esse estabelecimento permanece com o som alto ...  ...  Maringá  Paraná
# 4  na madrugada de terça para quarta (dia 08 para...  ...  Maringá  Paraná
#
#      Pais      DataInclusao_BR  \
# 0  Brasil  22:20:00 14-11-2022
# 1  Brasil  23:54:00 21-05-2022
# 2  Brasil  23:49:00 23-12-2022
# 3  Brasil  08:56:00 23-12-2023
# 4  Brasil  08:45:00 09-11-2022
#
#                                    endereco_completo   latitude  longitude  \
# 0    Alameda Amor Perfeito, 36, Maringá - PR, Brasil -23.360488 -52.014885
# 1  Alameda Das Alfazemas, 1968, Maringá - PR, Brasil -23.357035 -52.009594
# 2  Alameda Doutor João Paulino, 673, Maringá - PR... -23.400397 -51.921264
# 3  Avenida Advogado Horácio Raccanello Filho, 183... -23.420447 -51.924922
# 4  Avenida Advogado Horácio Raccanello Filho, 360... -23.423895 -51.914974
#
#                                   endereco_formatado cluster  y
# 0  Alameda Amor Perfeito - Conj. Hab. Joao de Bar...      -1  0
# 1  Alameda das Alfazemas - Conj. Hab. Joao de Bar...      -1  0
# 2  Alameda Dr. João Paulino, 673 - Jardim Alvorad...      25  3
# 3  Av. Advogado Horácio Raccanello Filho, 183 - Z...      -1  1
# 4  Av. Advogado Horácio Raccanello Filho, 3605 - ...      95  1
#
# [5 rows x 21 columns]

# %%
plt.scatter(df['longitude'], df['latitude'], c=df['y'])

# %%
model.inertia_
# Out:
# 0.86119739258446

# %%
wcss = []
for i in range(1,11):
    model = KMeans(n_clusters=i)
    y_kmeans = model.fit_predict(x)
    wcss.append(model.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
df = df[:2000]

cluster1 = df[['latitude', "longitude"]][df['y'] == 0].values.tolist()
cluster2 = df[['latitude', "longitude"]][df['y'] == 1].values.tolist()
cluster3 = df[['latitude', "longitude"]][df['y'] == 2].values.tolist()
cluster4 = df[['latitude', "longitude"]][df['y'] == 3].values.tolist()

# %%
import folium

key = "UYt1hZNFFGFt10Gokner"  # pegue no dashboard do MapTiler
map = folium.Map(location=[-23.420999, -51.933056], zoom_start=12, tiles=None)

folium.TileLayer(
    tiles=f"https://api.maptiler.com/maps/streets-v2/256/{{z}}/{{x}}/{{y}}.png?key={key}",
    attr="&copy; MapTiler &copy; OpenStreetMap contributors",
    name="MapTiler Streets",
).add_to(map)

for i in cluster1:
    folium.CircleMarker(i, radius=2,color='blue',fill_color='lightblue').add_to(map)
    
for i in cluster2:
    folium.CircleMarker(i, radius=2,color='red',fill_color='lightred').add_to(map)
    
for i in cluster3:
    folium.CircleMarker(i, radius=2,color='green',fill_color='lightgreen').add_to(map)

for i in cluster4:
    folium.CircleMarker(i, radius=2,color='orange',fill_color='lightorange').add_to(map)

map  # no Jupyter
#map.save("mapa.html")  # opcional
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e153b42b650498422207fc031ebe336a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e153b42b650498422207fc031ebe336a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e153b42b650498422207fc031ebe336a = L.map(
#                 &quot;map_e153b42b650498422207fc031ebe336a&quot;,
#                 {
#                     center: [-23.420999, -51.933056],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9242b4b5e3d9bf2c430d0028a4bcae7a = L.tileLayer(
#                 &quot;https://api.maptiler.com/maps/streets-v2/256/{z}/{x}/{y}.png?key=UYt1hZNFFGFt10Gokner&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; MapTiler \u0026copy; OpenStreetMap contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_b01e9b64fea0c69a72bcc04ac1570f45 = L.circleMarker(
#                 [-23.3604883, -52.0148854],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_7c95735750f78e8d3eff79f77944ca27 = L.circleMarker(
#                 [-23.3570352, -52.0095937],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_5b14a5e1f447ad09745d24663b98b96a = L.circleMarker(
#                 [-23.4008379, -51.9629859],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_1c60b5d632ba977d6acf028596b3e0f1 = L.circleMarker(
#                 [-23.4004627, -51.96500289999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_6455e74a42f01ea72484121e65ca2eaf = L.circleMarker(
#                 [-23.4004627, -51.96500289999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_830311ab4acde137bdc94f1f61327388 = L.circleMarker(
#                 [-23.4004627, -51.96500289999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e153b42b650498422207fc031ebe336a);
#
#
#             var circle_marker_d10e334296b3441822a36e41816beecf = L.circleMarker(
#                 [-23.4002454, -51.96524059999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot

# %%
import pandas as pd
import folium
from folium.plugins import TimestampedGeoJson

# 1) Ler e parsear data/hora (formato: "HH:MM:SS DD-MM-YYYY")
df = pd.read_csv("geocod_parcial_corrigido.csv")

df["DataInclusao"] = pd.to_datetime(
    df["DataInclusao_BR"],
    format="%H:%M:%S %d-%m-%Y",
    errors="coerce",
    dayfirst=True,
)

# 2) Limpeza básica
df = df.dropna(subset=["latitude", "longitude", "DataInclusao"]).copy()
df = df.sort_values("DataInclusao")

# 3) Renomear campo com acento (opcional)
if "Descrição" in df.columns:
    df = df.rename(columns={"Descrição": "Descricao"})

# 4) Construir o GeoJSON no formato que o TimestampedGeoJson espera
features = []
for _, r in df.iterrows():
    popup = (
        f"<b>Data/hora:</b> {r['DataInclusao'].strftime('%d/%m/%Y %H:%M:%S')}"
        f"<br><b>Endereço:</b> {str(r.get('endereco_completo', ''))}"
        f"<br><b>Descrição:</b> {str(r.get('Descricao', ''))}"
    )
    feat = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [float(r["longitude"]), float(r["latitude"])],
        },
        "properties": {
            # o plugin aceita 'times' (lista) ou 'time' (string); usaremos lista
            "times": [r["DataInclusao"].isoformat()],
            "popup": popup,
            # estilo do CircleMarker
            "style": {
                "radius": 5,
                "color": "#222222",
                "fillColor": "#ff4d4d",
                "fillOpacity": 0.7,
                "weight": 1,
            },
        },
    }
    features.append(feat)

geojson = {"type": "FeatureCollection", "features": features}

# 5) Criar o mapa com folium
m = folium.Map(location=[-23.42, -51.93], zoom_start=12, tiles="OpenStreetMap")

TimestampedGeoJson(
    data=geojson,
    period="P1D",                 # "PT1H" para hora-a-hora
    duration="P3D",               # rastro de 3 dias; use "PT0S" para sem rastro
    add_last_point=True,
    auto_play=True,
    loop=False,
    date_options="DD/MM/YYYY",
    time_slider_drag_update=True,
).add_to(m)

m.save("mapa_timeslider.html")
